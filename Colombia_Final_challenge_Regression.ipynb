# %%
import pandas as pd
import numpy as np
df = pd.read_csv("./Life_Expectancy_Data.csv")
pd.set_option('display.max_columns', None)

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   BMI  \
# 0             62     0.01               71.279624         65.0     1154  19.1
# 1             64     0.01               73.523582         62.0      492  18.6
# 2             66     0.01               73.219243         64.0      430  18.1
# 3             69     0.01               78.184215         67.0     2787  17.6
# 4             71     0.01                7.097109         68.0     3013  17.2
#
#    under_five deaths  Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 0                 83    6.0               8.16        65.0       0.1
# 1                 86   58.0               8.18        62.0       0.1
# 2                 89   62.0               8.13        64.0       0.1
# 3                 93   67.0               8.52        67.0       0.1
# 4                 97   68.0               7.87        68.0       0.1
#
#           GDP  Population  thinness 1-19 years  thinness 5_9 years  \
# 0  584.259210  33736494.0                 17.2                17.3
# 1  612.696514    327582.0                 17.5                17.5
# 2  631.744976  31731688.0                 17.7                17.7
# 3  669.959000   3696958.0                 17.9                18.0
# 4   63.537231   2978599.0                 18.2                18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5

# %%
col_df = df.loc[(df['Country'] =='Colombia')] 
#& (df['Year'] != 2015)
col_df
# Out:
#       Country  Year      Status  Life expectancy  Adult Mortality  \
# 576  Colombia  2015  Developing             74.8            143.0
# 577  Colombia  2014  Developing             74.6            144.0
# 578  Colombia  2013  Developing             74.4            145.0
# 579  Colombia  2012  Developing             74.3            143.0
# 580  Colombia  2011  Developing             74.2            144.0
# 581  Colombia  2010  Developing             73.6             15.0
# 582  Colombia  2009  Developing             73.6             15.0
# 583  Colombia  2008  Developing             73.5            146.0
# 584  Colombia  2007  Developing             73.5            144.0
# 585  Colombia  2006  Developing             73.1            147.0
# 586  Colombia  2005  Developing             73.1            144.0
# 587  Colombia  2004  Developing             72.8            148.0
# 588  Colombia  2003  Developing             72.4             15.0
# 589  Colombia  2002  Developing             71.8            163.0
# 590  Colombia  2001  Developing             71.5            165.0
# 591  Colombia  2000  Developing             71.4            167.0
#
#      infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 576             10      NaN                0.000000         91.0        1
# 577             11     4.38             1435.487755          9.0        0
# 578             11     4.41               15.162555         91.0        1
# 579             11     4.44             1487.896562         92.0        1
# 580             12     4.37              184.307362         85.0        6
# 581             12     4.28              113.243635         88.0        0
# 582             13     4.34              941.646405         92.0        0
# 583             14     4.45              978.070410         92.0        0
# 584             14     4.66              780.594675         93.0        0
# 585             15     4.53               62.437108         93.0        0
# 586             15     4.38              531.980818         93.0        0
# 587             16     4.26               42.179564         89.0        0
# 588             16     4.25              417.803890         92.0        0
# 589             17     4.45              393.877363         78.0      139
# 590             17     4.43              404.420586          8.0        3
# 591             18     4.66              477.134181         78.0        1
#
#       BMI  under_five deaths  Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 576  57.9                 12   91.0                NaN        91.0       0.1
# 577  57.2                 12    9.0               7.20         9.0       0.1
# 578  56.4                 13   91.0               6.84        91.0       0.1
# 579  55.7                 13   91.0               6.93        91.0       0.1
# 580  55.0                 14   85.0               6.64        85.0       0.1
# 581  54.2                 15   88.0               6.76        88.0       0.1
# 582  53.5                 15   92.0               7.10        92.0       0.1
# 583  52.8                 16   92.0               6.62        92.0       0.1
# 584  52.0                 17   93.0               6.25        93.0       0.1
# 585  51.3                 17   94.0               6.11        93.0       0.1
# 586   5.5                 18   93.0               5.82        93.0       0.1
# 587  49.8                 19   89.0               5.37        89.0       0.1
# 588  49.0                 19   92.0               5.92        92.0       0.1
# 589  48.2                 20   83.0               5.67        81.0       0.1
# 590  47.5                 21   83.0               5.96         8.0       0.1
# 591  46.7                 21   82.0               5.91        79.0       0.1
#
#              GDP  Population  thinness 1-19 years  thinness 5_9 years  \
# 576   644.525556  48228697.0                  2.1                 1.9
# 577  7913.383432  47791911.0                  2.1                 1.9
# 578    83.586300  47342981.0                  2.1                 1.9
# 579  7884.984429  46881475.0                  2.1                 1.9
# 580  7227.739680   4646646.0                  2.2                 2.0
# 581   625.655440   4591897.0                  2.2                 2.0
# 582  5148.422113  45416181.0                  2.2                 2.0
# 583  5433.724500   4491544.0                  2.3                 2.0
# 584  4674.219610  44374572.0                  2.3                 2.1
# 585   379.787760  43835722.0                  2.3                 2.1
# 586  3386.256000  43285634.0                  2.4                 2.1
# 587   274.249442  42724163.0                  2.4                 2.2
# 588  2246.257472  42152151.0                  2.5                 2.2
# 589  2355.725857  41572491.0                  2.5                 2.3
# 590  2395.856551    498899.0                  2.5                 2.3
# 591  2472.197831    443958.0                  2.6                 2.3
#
#      Income composition of resources  Schooling
# 576                            0.724       13.6
# 577                            0.720       13.6
# 578                            0.712       13.3
# 579                            0.707       13.2
# 580                            0.700       13.0
# 581                            0.695       12.8
# 582                            0.691       12.4
# 583                            0.683       12.2
# 584                            0.675       11.9
# 585                            0.669       11.5
# 586                            0.658       11.1
# 587                            0.658       11.3
# 588                            0.659       11.6
# 589                            0.656       11.5
# 590                            0.653       11.4
# 591                            0.650       11.3

# %%
col_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 576 to 591
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          16 non-null     object
#  1   Year                             16 non-null     int64
#  2   Status                           16 non-null     object
#  3   Life expectancy                  16 non-null     float64
#  4   Adult Mortality                  16 non-null     float64
#  5   infant deaths                    16 non-null     int64
#  6   Alcohol                          15 non-null     float64
#  7   percentage expenditure           16 non-null     float64
#  8   Hepatitis B                      16 non-null     float64
#  9   Measles                          16 non-null     int64
#  10  BMI                              16 non-null     float64
#  11  under_five deaths                16 non-null     int64
#  12  Polio                            16 non-null     float64
#  13  Total expenditure                15 non-null     float64
#  14  Diphtheria                       16 non-null     float64
#  15  HIV/AIDS                         16 non-null     float64
#  16  GDP                              16 non-null     float64
#  17  Population                       16 non-null     float64
#  18  thinness 1-19 years              16 non-null     float64
#  19  thinness 5_9 years               16 non-null     float64
#  20  Income composition of resources  16 non-null     float64
#  21  Schooling                        16 non-null     float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 2.9+ KB

# %%
corr_matrix = col_df.corr() #compute the standard correlation coefficient

# %%
corr_matrix['Life expectancy'].sort_values(ascending=False) 
#cor(i,j) = cov(i,j)/[stdev(i)*stdev(j)]
#If the values of the ith or jth variable do not vary, then the respective standard deviation will be zero and so will the denominator of the fraction. 
#Thus, the correlation will be NaN
# Out:
# Life expectancy                    1.000000e+00
# Year                               9.786803e-01
# Income composition of resources    9.310496e-01
# Schooling                          8.676268e-01
# Total expenditure                  7.844116e-01
# Population                         3.912479e-01
# GDP                                3.304676e-01
# BMI                                3.263263e-01
# percentage expenditure             2.000678e-01
# Hepatitis B                        1.758169e-01
# Diphtheria                         1.596952e-01
# HIV/AIDS                           9.353235e-15
# Adult Mortality                   -8.891753e-02
# Polio                             -2.137951e-01
# Alcohol                           -2.227782e-01
# Measles                           -3.662767e-01
# thinness 1-19 years               -9.638841e-01
# infant deaths                     -9.691899e-01
# thinness 5_9 years                -9.728343e-01
# under_five deaths                 -9.766431e-01
# Name: Life expectancy, dtype: float64

# %%
# x and y defined as a numpy.ndaray
x = col_df['Year'].values
y = col_df['Life expectancy'].values

# %%
plt.scatter(x, y) #8.602480e-01

# %%
from sklearn.model_selection import train_test_split
#split the data set
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
# array([2002, 2004, 2007, 2006, 2013, 2000, 2011, 2008, 2005, 2003, 2012,
#        2009], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
#Load and fit the model
regressor = LinearRegression() #Create a regressor variable and instantiate your LinearRegression class
regressor.fit(X_train.reshape(-1, 1), y_train.reshape(-1, 1))
# Out:
# LinearRegression()

# %%
regressor.score(X_train.reshape(-1, 1), y_train.reshape(-1, 1)) # model score
# Out:
# 0.954995908062697

# %%
#testing the model
regressor.predict(X_test.reshape(-1, 1))
# Out:
# array([[75.07030686],
#        [74.84287004],
#        [73.93312274],
#        [71.88619134]])

# %%
y_test
# Out:
# array([74.8, 74.6, 73.6, 71.5])

# %%
regressor.score(X_test.reshape(-1,1),y_test.reshape(-1,1))
# Out:
# 0.942728563310918

# %%
# Ploting
plt.plot( X_train, regressor.predict(X_train.reshape(-1, 1)))
plt.scatter( X_train, y_train, c='r')
plt.title("Life espectancy in Colombia VS Year (Training set)")
plt.xlabel("Year")
plt.ylabel("Life expectancy")
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.plot( X_test, regressor.predict(X_test.reshape(-1, 1)))
plt.scatter( X_test, y_test, c='r')
plt.title("Life espectancy in Colombia VS Year (Test set)")
plt.xlabel("Year")
plt.ylabel("Life espectancy")
# Out:
# Text(0, 0.5, 'Life espectancy')

# %%
X_test1=np.array([2100])
regressor.predict(X_test1.reshape(-1, 1))
# Out:
# array([[94.40243682]])
