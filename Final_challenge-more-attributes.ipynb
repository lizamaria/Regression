# %%
import pandas as pd
import numpy as np
df = pd.read_csv("./Life_Expectancy_Data.csv")
pd.set_option('display.max_columns', None)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df0 = df[(df['Country'].isin(['Belgium', 'Colombia', 'Italy', 'China', 'El Salvador'])) & (df['Year'] != 2015)]
(df['Year'].isin([2004, 2005, 2015]))
df0
#df2 = df0.loc[(df0['Country'] =='Colombia')|(df0['Country'] =='Italy')]
#|(df['Country'] =='China')|(df['Country'] =='El Salvador')
# Out:
#       Country  Year     Status  Life expectancy  Adult Mortality  \
# 241   Belgium  2014  Developed             89.0             76.0
# 242   Belgium  2013  Developed             87.0             77.0
# 243   Belgium  2012  Developed             83.0             78.0
# 244   Belgium  2011  Developed             83.0              8.0
# 245   Belgium  2010  Developed             80.0             81.0
# ...       ...   ...        ...              ...              ...
# 1293    Italy  2004  Developed             89.0             66.0
# 1294    Italy  2003  Developed             79.9             72.0
# 1295    Italy  2002  Developed             80.0             72.0
# 1296    Italy  2001  Developed             79.8             75.0
# 1297    Italy  2000  Developed             79.4             77.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 241               0    12.60             7163.348923         98.0       70
# ...

# %%
df0['Country'].value_counts()
# Out:
# China          15
# Colombia       15
# El Salvador    15
# Belgium        15
# Italy          15
# Name: Country, dtype: int64

# %%
corr_matrix = df0.corr() #compute the standard correlation coefficient
corr_matrix['Life expectancy'].sort_values(ascending=False)
# Out:
# Life expectancy                    1.000000
# Income composition of resources    0.886940
# Alcohol                            0.811110
# Schooling                          0.763040
# GDP                                0.630251
# percentage expenditure             0.623361
# BMI                                0.323823
# Polio                              0.319513
# Diphtheria                         0.308353
# Year                               0.267915
# Population                         0.244716
# Hepatitis B                        0.233716
# Total expenditure                  0.075440
# Measles                           -0.211895
# under_five deaths                 -0.276969
# infant deaths                     -0.277577
# Adult Mortality                   -0.440628
# HIV/AIDS                          -0.496610
# thinness 1-19 years               -0.574280
# thinness 5_9 years                -0.590631
# Name: Life expectancy, dtype: float64

# %%
# x and y defined as a numpy.ndaray
x = df0['Year'].values
y = df0['Life expectancy'].values

# %%
plt.scatter(x, y)

# %%
x1 = df['Year'].values
#x0 = df['country'].values
x2 = df['Adult Mortality'].values
x3 = df['infant deaths'].values
x4 = df['Population'].values
x5= df['Schooling'].values
ones_vec = np.ones(30)
X = np.array([x1, ones_vec]).T
print(x.shape)
print(ones_vec.shape)
X.shape
y = df['Life expectancy'].values
