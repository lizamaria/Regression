# %%
import pandas as pd
import numpy as np
df = pd.read_csv("./Life_Expectancy_Data.csv")
pd.set_option('display.max_columns', None)

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   BMI  \
# 0             62     0.01               71.279624         65.0     1154  19.1
# 1             64     0.01               73.523582         62.0      492  18.6
# 2             66     0.01               73.219243         64.0      430  18.1
# 3             69     0.01               78.184215         67.0     2787  17.6
# 4             71     0.01                7.097109         68.0     3013  17.2
#
#    under_five deaths  Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 0                 83    6.0               8.16        65.0       0.1
# 1                 86   58.0               8.18        62.0       0.1
# 2                 89   62.0               8.13        64.0       0.1
# 3                 93   67.0               8.52        67.0       0.1
# 4                 97   68.0               7.87        68.0       0.1
#
#           GDP  Population  thinness 1-19 years  thinness 5_9 years  \
# 0  584.259210  33736494.0                 17.2                17.3
# 1  612.696514    327582.0                 17.5                17.5
# 2  631.744976  31731688.0                 17.7                17.7
# 3  669.959000   3696958.0                 17.9                18.0
# 4   63.537231   2978599.0                 18.2                18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5

# %%
sal_df = df.loc[(df['Country'] =='El Salvador') & (~df['Year'].isin([2002, 2006]))]
#& (df['Year'] != 2015)
sal_df
# Out:
#          Country  Year      Status  Life expectancy  Adult Mortality  \
# 818  El Salvador  2015  Developing             73.5            178.0
# 819  El Salvador  2014  Developing             73.3            181.0
# 820  El Salvador  2013  Developing             73.0            184.0
# 821  El Salvador  2012  Developing             73.0            181.0
# 822  El Salvador  2011  Developing             72.0            197.0
# 823  El Salvador  2010  Developing             72.0            191.0
# 824  El Salvador  2009  Developing             71.4             23.0
# 825  El Salvador  2008  Developing             71.7            194.0
# 826  El Salvador  2007  Developing             71.2             23.0
# 828  El Salvador  2005  Developing             71.0            213.0
# 829  El Salvador  2004  Developing             70.0            215.0
# 830  El Salvador  2003  Developing             69.9             29.0
# 832  El Salvador  2001  Developing             68.9            219.0
# 833  El Salvador  2000  Developing             69.0            218.0
#
#      infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 818              2      NaN                0.000000         91.0        0
# 819              2     2.52              665.726025         93.0        0
# 820              2     2.42              653.692502         92.0        0
# 821              2     2.48              591.775757         92.0        0
# 822              2     2.37              549.278308         89.0        0
# 823              2     2.36              469.390419         89.0        0
# 824              2     2.55              416.433840         91.0        0
# 825              2     2.68               53.959499         98.0        0
# 826              2     2.83               52.301722         99.0        0
# 828              3     2.77              440.602704         89.0        0
# 829              3     2.90              398.605832          9.0        0
# 830              3     3.10              400.134297         94.0        0
# 832              4     2.88              332.105659         75.0        2
# 833              4     2.79              353.669033         99.0        0
#
#       BMI  under_five deaths  Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 818  56.1                  2   92.0                NaN        91.0       0.2
# 819  55.4                  2   93.0               6.77        94.0       0.2
# 820  54.7                  2   92.0               6.95        92.0       0.2
# 821  54.1                  2   93.0               6.70        92.0       0.3
# 822  53.4                  2    9.0               6.81        89.0       0.3
# 823  52.8                  2   89.0               6.91        89.0       0.3
# 824  52.1                  2   91.0               6.83        91.0       0.3
# 825  51.4                  3   98.0               6.21        98.0       0.3
# 826   5.8                  3   99.0               6.32        99.0       0.3
# 828  49.4                  3   89.0               7.19        89.0       0.2
# 829  48.6                  3    9.0               7.30         9.0       0.3
# 830  47.8                  4   93.0               7.61        94.0       0.3
# 832  46.2                  4   94.0               8.20        92.0       0.4
# 833  45.3                  5   98.0               8.17        99.0       0.4
#
#              GDP  Population  thinness 1-19 years  thinness 5_9 years  \
# 818  4127.117750   6312478.0                  1.6                 1.5
# 819  3988.771871   6281189.0                  1.6                 1.6
# 820  3895.664491    625777.0                  1.6                 1.6
# 821  3827.786267   6221246.0                  1.6                 1.6
# 822  3736.587130    619256.0                  1.7                 1.6
# 823  3474.392445   6164626.0                  1.7                 1.6
# 824  3366.482133   6137276.0                  1.7                 1.6
# 825   357.347674     61131.0                  1.8                 1.7
# 826   334.838170    683475.0                  1.8                 1.7
# 828  2835.281237    628961.0                  1.9                 1.8
# 829  2632.799420      6775.0                  1.9                 1.8
# 830  2519.737387   5971535.0                  2.0                 1.9
# 832  2338.772244    595962.0                  2.1                 2.0
# 833  2238.411600   5867626.0                  2.1                 2.0
#
#      Income composition of resources  Schooling
# 818                            0.678       13.2
# 819                            0.676       13.2
# 820                            0.675       13.2
# 821                            0.670       13.2
# 822                            0.666       13.0
# 823                            0.662       12.9
# 824                            0.662       12.8
# 825                            0.659       13.4
# 826                            0.657       12.9
# 828                            0.644       12.7
# 829                            0.636       12.4
# 830                            0.628       12.0
# 832                            0.615       11.6
# 833                            0.607       11.3

# %%
sal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 818 to 833
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          14 non-null     object
#  1   Year                             14 non-null     int64
#  2   Status                           14 non-null     object
#  3   Life expectancy                  14 non-null     float64
#  4   Adult Mortality                  14 non-null     float64
#  5   infant deaths                    14 non-null     int64
#  6   Alcohol                          13 non-null     float64
#  7   percentage expenditure           14 non-null     float64
#  8   Hepatitis B                      14 non-null     float64
#  9   Measles                          14 non-null     int64
#  10  BMI                              14 non-null     float64
#  11  under_five deaths                14 non-null     int64
#  12  Polio                            14 non-null     float64
#  13  Total expenditure                13 non-null     float64
#  14  Diphtheria                       14 non-null     float64
#  15  HIV/AIDS                         14 non-null     float64
#  16  GDP                              14 non-null     float64
#  17  Population                       14 non-null     float64
#  18  thinness 1-19 years              14 non-null     float64
#  19  thinness 5_9 years               14 non-null     float64
#  20  Income composition of resources  14 non-null     float64
#  21  Schooling                        14 non-null     float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 2.5+ KB

# %%
corr_matrix = sal_df.corr() #compute the standard correlation coefficient

# %%
corr_matrix['Life expectancy'].sort_values(ascending=False) 
#cor(i,j) = cov(i,j)/[stdev(i)*stdev(j)]
#If the values of the ith or jth variable do not vary, then the respective standard deviation will be zero and so will the denominator of the fraction. 
#Thus, the correlation will be NaN
# Out:
# Life expectancy                    1.000000
# Year                               0.985682
# Income composition of resources    0.971097
# Schooling                          0.908134
# GDP                                0.502353
# BMI                                0.306586
# Hepatitis B                        0.305152
# Population                         0.243946
# Diphtheria                         0.216228
# percentage expenditure             0.174052
# Polio                              0.084942
# Adult Mortality                    0.026644
# Measles                           -0.474857
# HIV/AIDS                          -0.763514
# Total expenditure                 -0.772948
# Alcohol                           -0.783783
# infant deaths                     -0.878029
# under_five deaths                 -0.884640
# thinness 5_9 years                -0.938983
# thinness 1-19 years               -0.971611
# Name: Life expectancy, dtype: float64

# %%
# x and y defined as a numpy.ndaray
x = sal_df['Year'].values
y = sal_df['Life expectancy'].values

# %%
plt.scatter(x, y) #0.9827338

# %%
from sklearn.model_selection import train_test_split
#split the data set
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
# array([2001, 2010, 2007, 2013, 2014, 2000, 2011, 2008, 2004, 2012, 2009],
#       dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
#Load and fit the model
regressor = LinearRegression() #Create a regressor variable and instantiate your LinearRegression class
regressor.fit(X_train.reshape(-1, 1), y_train.reshape(-1, 1))
# Out:
# LinearRegression()

# %%
regressor.score(X_train.reshape(-1, 1), y_train.reshape(-1, 1)) # model score
# Out:
# 0.9769685219499924

# %%
#testing the model
regressor.predict(X_test.reshape(-1, 1))
# Out:
# array([[70.41160494],
#        [69.76617284],
#        [73.63876543]])

# %%
y_test
# Out:
# array([71. , 69.9, 73.5])

# %%
regressor.score(X_test.reshape(-1,1),y_test.reshape(-1,1))
# Out:
# 0.9436766450492966

# %%
# Ploting
plt.plot( X_train, regressor.predict(X_train.reshape(-1, 1)))
plt.scatter( X_train, y_train, c='r')
plt.title("Life espectancy in Colombia VS Year (Training set)")
plt.xlabel("Year")
plt.ylabel("Life expectancy")
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.plot( X_test, regressor.predict(X_test.reshape(-1, 1)))
plt.scatter( X_test, y_test, c='r')
plt.title("Life espectancy VS Year (Test set)")
plt.xlabel("Year")
plt.ylabel("Life espectancy")
# Out:
# Text(0, 0.5, 'Life espectancy')

# %%
X_test1=np.array([2100])
regressor.predict(X_test1.reshape(-1, 1))
# Out:
# array([[101.06962963]])
