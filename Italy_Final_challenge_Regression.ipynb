# %%
import pandas as pd
import numpy as np
df = pd.read_csv("./Life_Expectancy_Data.csv")
pd.set_option('display.max_columns', None)

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   BMI  \
# 0             62     0.01               71.279624         65.0     1154  19.1
# 1             64     0.01               73.523582         62.0      492  18.6
# 2             66     0.01               73.219243         64.0      430  18.1
# 3             69     0.01               78.184215         67.0     2787  17.6
# 4             71     0.01                7.097109         68.0     3013  17.2
#
#    under_five deaths  Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 0                 83    6.0               8.16        65.0       0.1
# 1                 86   58.0               8.18        62.0       0.1
# 2                 89   62.0               8.13        64.0       0.1
# 3                 93   67.0               8.52        67.0       0.1
# 4                 97   68.0               7.87        68.0       0.1
#
#           GDP  Population  thinness 1-19 years  thinness 5_9 years  \
# 0  584.259210  33736494.0                 17.2                17.3
# 1  612.696514    327582.0                 17.5                17.5
# 2  631.744976  31731688.0                 17.7                17.7
# 3  669.959000   3696958.0                 17.9                18.0
# 4   63.537231   2978599.0                 18.2                18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5

# %%
ita_df = df.loc[(df['Country'] =='Italy') & (~df['Year'].isin([2004, 2005]))]
ita_df
# Out:
#      Country  Year     Status  Life expectancy  Adult Mortality  \
# 1282   Italy  2015  Developed             82.7             56.0
# 1283   Italy  2014  Developed             82.5             57.0
# 1284   Italy  2013  Developed             82.3             58.0
# 1285   Italy  2012  Developed             82.0              6.0
# 1286   Italy  2011  Developed             82.0              6.0
# 1287   Italy  2010  Developed             81.8              6.0
# 1288   Italy  2009  Developed             81.6             61.0
# 1289   Italy  2008  Developed             81.5             61.0
# 1290   Italy  2007  Developed             81.3             63.0
# 1291   Italy  2006  Developed             81.2             65.0
# 1294   Italy  2003  Developed             79.9             72.0
# 1295   Italy  2002  Developed             80.0             72.0
# 1296   Italy  2001  Developed             79.8             75.0
# 1297   Italy  2000  Developed             79.4             77.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 1282              1      NaN                0.000000         93.0      159
# 1283              2     7.56             4831.644796         95.0        0
# 1284              2     7.35              483.191684         96.0        0
# 1285              2     7.49             4793.904924         96.0      376
# 1286              2     6.98             5439.691769         96.0     5189
# 1287              2     6.95             5219.668802         96.0      372
# 1288              2     7.25             5243.316638         96.0      351
# 1289              2     7.96               66.378405         96.0     1617
# 1290              2     8.37             5228.821581         97.0      321
# 1291              2     8.44              473.191545         96.0      439
# 1294              2     9.30             3519.258515         95.0    10982
# 1295              2     9.25             2883.334911         95.0     9385
# 1296              2     9.69                3.122230         95.0        0
# 1297              3     9.78               31.505822         94.0     1457
#
#        BMI  under_five deaths  Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 1282  63.6                  2   93.0                NaN        93.0       0.1
# 1283  63.1                  2   95.0               9.25        95.0       0.1
# 1284  62.6                  2   96.0               9.22        96.0       0.1
# 1285  62.1                  2   96.0               9.28        97.0       0.1
# 1286  61.5                  2   96.0               9.27        96.0       0.1
# 1287  61.0                  2   96.0               9.42        96.0       0.1
# 1288   6.5                  2   96.0               9.41        96.0       0.1
# 1289  59.9                  2   96.0               8.89        96.0       0.1
# 1290  59.4                  2   97.0               8.48        97.0       0.1
# 1291  58.8                  2   97.0               8.82        96.0       0.1
# 1294  57.0                  3   97.0               8.17        96.0       0.1
# 1295  56.4                  3   96.0               8.23        93.0       0.1
# 1296  55.7                  3   96.0               8.11        93.0       0.1
# 1297  55.0                  3   97.0               7.91        87.0       0.1
#
#               GDP  Population  thinness 1-19 years  thinness 5_9 years  \
# 1282    349.14755    673582.0                  0.6                 0.6
# 1283  35396.66517    678914.0                  0.6                 0.6
# 1284   3537.27441   6233948.0                  0.5                 0.6
# 1285  34814.12436  59539717.0                  0.5                 0.6
# 1286  38334.68477  59379449.0                  0.5                 0.5
# 1287  35849.37364  59277417.0                  0.5                 0.5
# 1288  36976.84512   5995365.0                  0.5                 0.5
# 1289    464.18465  58826731.0                  0.5                 0.5
# 1290  37698.78573   5843831.0                  0.5                 0.5
# 1291   3341.74820  58143979.0                  0.5                 0.5
# 1294  27387.22580   5731323.0                  0.5                 0.5
# 1295  22196.57360     57597.0                  0.5                 0.5
# 1296     24.81900    569741.0                  0.5                 0.5
# 1297    251.24260   5694218.0                  0.5                 0.5
#
#       Income composition of resources  Schooling
# 1282                            0.881       16.3
# 1283                            0.877       16.3
# 1284                            0.876       16.5
# 1285                            0.877       16.6
# 1286                            0.872       16.4
# 1287                            0.869       16.4
# 1288                            0.868       16.3
# 1289                            0.866       16.3
# 1290                            0.862       16.1
# 1291                            0.856       16.0
# 1294                            0.841       15.4
# 1295                            0.836       15.2
# 1296                            0.828       14.9
# 1297                            0.823       14.8

# %%
ita_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 1282 to 1297
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          14 non-null     object
#  1   Year                             14 non-null     int64
#  2   Status                           14 non-null     object
#  3   Life expectancy                  14 non-null     float64
#  4   Adult Mortality                  14 non-null     float64
#  5   infant deaths                    14 non-null     int64
#  6   Alcohol                          13 non-null     float64
#  7   percentage expenditure           14 non-null     float64
#  8   Hepatitis B                      14 non-null     float64
#  9   Measles                          14 non-null     int64
#  10  BMI                              14 non-null     float64
#  11  under_five deaths                14 non-null     int64
#  12  Polio                            14 non-null     float64
#  13  Total expenditure                13 non-null     float64
#  14  Diphtheria                       14 non-null     float64
#  15  HIV/AIDS                         14 non-null     float64
#  16  GDP                              14 non-null     float64
#  17  Population                       14 non-null     float64
#  18  thinness 1-19 years              14 non-null     float64
#  19  thinness 5_9 years               14 non-null     float64
#  20  Income composition of resources  14 non-null     float64
#  21  Schooling                        14 non-null     float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 2.5+ KB

# %%
corr_matrix = ita_df.corr() #compute the standard correlation coefficient

# %%
corr_matrix['Life expectancy'].sort_values(ascending=False) 
#cor(i,j) = cov(i,j)/[stdev(i)*stdev(j)]
#If the values of the ith or jth variable do not vary, then the respective standard deviation will be zero and so will the denominator of the fraction. 
#Thus, the correlation will be NaN
# Out:
# Life expectancy                    1.000000
# Year                               0.986873
# Income composition of resources    0.984423
# Schooling                          0.936924
# Total expenditure                  0.933033
# thinness 5_9 years                 0.659500
# Diphtheria                         0.553300
# thinness 1-19 years                0.513638
# Population                         0.290717
# percentage expenditure             0.278000
# GDP                                0.260004
# Hepatitis B                        0.173546
# BMI                                0.109857
# Measles                           -0.489130
# Adult Mortality                   -0.551423
# infant deaths                     -0.597005
# Polio                             -0.601724
# under_five deaths                 -0.914651
# Alcohol                           -0.936763
# HIV/AIDS                                NaN
# Name: Life expectancy, dtype: float64

# %%
# x and y defined as a numpy.ndaray
x = ita_df['Year'].values
y = ita_df['Life expectancy'].values

# %%
plt.scatter(x, y) #8.602480e-01

# %%
from sklearn.model_selection import train_test_split
#split the data set
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
# array([2001, 2010, 2007, 2013, 2014, 2000, 2011, 2008, 2003, 2012, 2009],
#       dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
#Load and fit the model
regressor = LinearRegression() #Create a regressor variable and instantiate your LinearRegression class
regressor.fit(X_train.reshape(-1, 1), y_train.reshape(-1, 1))
# Out:
# LinearRegression()

# %%
regressor.score(X_train.reshape(-1, 1), y_train.reshape(-1, 1)) # model score
# Out:
# 0.9773357060708969

# %%
#testing the model
regressor.predict(X_test.reshape(-1, 1))
# Out:
# array([[80.83747036],
#        [79.9487747 ],
#        [82.83703557]])

# %%
y_test
# Out:
# array([81.2, 80. , 82.7])

# %%
regressor.score(X_test.reshape(-1,1),y_test.reshape(-1,1))
# Out:
# 0.9582430267021023

# %%
# Ploting
plt.plot( X_train, regressor.predict(X_train.reshape(-1, 1)))
plt.scatter( X_train, y_train, c='r')
plt.title("Life espectancy in Colombia VS Year (Training set)")
plt.xlabel("Year")
plt.ylabel("Life expectancy")
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.plot( X_test, regressor.predict(X_test.reshape(-1, 1)))
plt.scatter( X_test, y_test, c='r')
plt.title("Life espectancy VS Year (Test set)")
plt.xlabel("Year")
plt.ylabel("Life espectancy")
# Out:
# Text(0, 0.5, 'Life espectancy')

# %%
X_test1=np.array([2100])
regressor.predict(X_test1.reshape(-1, 1))
# Out:
# array([[101.72181818]])
